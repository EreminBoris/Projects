# %% [markdown]
# <a href="https://colab.research.google.com/github/EreminBoris/Projects/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
pd.set_option("display.float_format", "{:0.0f}".format)
data1 = pd.read_excel("1.xlsx", dtype={'ИД услуги': str})
data2 = pd.read_excel("2.xlsx", dtype={'ИД услуги': str}); data2 = data2.drop (index=0)
data3 = pd.read_excel("3.xlsx", dtype={'ИД услуги': str}); data3 = data3.drop (index=0)
data4 = pd.read_excel("4.xlsx", dtype={'ИД услуги': str}); data4 = data4.drop (index=0)
data5 = pd.read_excel("5.xlsx", dtype={'ИД услуги': str}); data5 = data5.drop (index=0)
data6 = pd.read_excel("6.xlsx", dtype={'ИД услуги': str}); data6 = data6.drop (index=0)
data7 = pd.read_excel("7.xlsx", dtype={'ИД услуги': str}); data7 = data7.drop (index=0)
data8 = pd.read_excel("8.xlsx", dtype={'ИД услуги': str}); data8 = data8.drop (index=0)
data9 = pd.read_excel("9.xlsx", dtype={'ИД услуги': str}); data9 = data9.drop (index=0)
data10 = pd.read_excel("10.xlsx", dtype={'ИД услуги': str}); data10 = data10.drop (index=0)
data11 = pd.read_excel("11.xlsx", dtype={'ИД услуги': str}); data11 = data11.drop (index=0)
data12 = pd.read_excel("12.xlsx", dtype={'ИД услуги': str}); data12 = data12.drop (index=0)
data13 = pd.read_excel("13.xlsx", dtype={'ИД услуги': str}); data13 = data13.drop (index=0)
data14 = pd.read_excel("14.xlsx", dtype={'ИД услуги': str}); data14 = data14.drop (index=0)
data15 = pd.read_excel("15.xlsx", dtype={'ИД услуги': str}); data15 = data15.drop (index=0)
data16 = pd.read_excel("16.xlsx", dtype={'ИД услуги': str}); data16 = data16.drop (index=0)
data17 = pd.read_excel("17.xlsx", dtype={'ИД услуги': str}); data17 = data17.drop (index=0)
data18 = pd.read_excel("18.xlsx", dtype={'ИД услуги': str}); data18 = data18.drop (index=0)
data19 = pd.read_excel("19.xlsx", dtype={'ИД услуги': str}); data19 = data19.drop (index=0)
data20 = pd.read_excel("20.xlsx", dtype={'ИД услуги': str}); data20 = data20.drop (index=0)
data21 = pd.read_excel("21.xlsx", dtype={'ИД услуги': str}); data21 = data21.drop (index=0)
data22 = pd.read_excel("22.xlsx", dtype={'ИД услуги': str}); data22 = data22.drop (index=0)
data23 = pd.read_excel("23.xlsx", dtype={'ИД услуги': str}); data23 = data23.drop (index=0)
data24 = pd.read_excel("24.xlsx", dtype={'ИД услуги': str}); data24 = data24.drop (index=0)
gos_data = pd.read_excel("77.xlsx", dtype={'ИД услуги': str})
concat_data = pd.concat([data1, data2, data3, data4, data5, data6, data7, data8, data9, data10, data11, data12, data13, data14, data15, data16, data17, data18, data19, data20, data21, data22, data23, data24], ignore_index=True)
concat_data.to_excel("data_sets.xlsx")
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# /usr/local/lib/python3.10/dist-packages/openpyxl/styles/stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
concat_data
# Out:
#                                             Организация  \
# 0                                                   NaN
# 1     Выдача документов (единого жилищного документа...
# 2     Выдача справок, выписок из похозяйственных и д...
# 3     Выдача документов (единого жилищного документа...
# 4     Предоставление информации справочного характер...
# ...                                                 ...
# 2389  Предоставление недвижимого имущества, находяще...
# 2390  Предоставление в собственность, аренду, постоя...
# 2391  Отнесение земель или земельных участков в сост...
# 2392  Установление сервитута в отношении земельного ...
# 2393                     Присвоение спортивных разрядов
#
#                               Ответственная организация            ИД услуги  \
# 0                                                   NaN                  NaN
# 1           Управление земельно-имущественных отношений  5921400010000006850
# ...

# %%
data = concat_data

# %%
data['sum_electron'] = data['Общее количество заявлений (запросов) о предоставлении государственной (муниципальной) услуги, поступивших в электронном виде']

# %%
data.groupby('Организация').sum()
# Out:
#                                                                             Ответственная организация  \
# Организация
# «Предоставление информации из федеральной базы ...      Управление образования и социального развития
# Безвозмездная передача в муниципальную собствен...  Комитет ИЗОУправление по имуществу и ГДУправле...
# Безвозмездная передача в муниципальную собствен...                                                УЖП
# Безвозмездная передача в собственность граждан ...  Медянское сельское поселение Ординского муници...
# Безвозмездная передача в собственность граждан ...  УИЗОУЖПУправление по имуществу и ГДУправление ...
# ...                                                                                               ...
# Утверждение и выдача схемы расположения границ ...  Администрация Ординского муниципального округа...
# Утверждение карты-плана территории по результат...                       Управление по имуществу и ГД
# ...

# %%
gos_data
# Out:
#                                           Организация            ИД услуги  \
# 0                                                 NaN                  NaN
# 1   Согласование проектной документации на проведе...  5900000000216406920
# 2   Выдача задания, разрешения на проведение работ...  5900000010000063102
# 3   Выдача выписки из Единого государственного рее...  5900000010000064159
# 4   Выдача паспорта объекта культурного наследия, ...  5900000010000136673
# ..                                                ...                  ...
# 87  Прием и рассмотрение деклараций о характеристи...  5900000000218504981
# 88  Прием и рассмотрение замечаний, связанных с оп...  5900000000218521311
# 89  Прием и рассмотрение заявлений об исправлении ...  5900000000218540751
# 90  Прием и рассмотрение заявлений об установлении...  5900000000226992824
# 91  Оформление, государственная регистрация и выда...  5900000000221164310
#
#                             Ответственная организация  \
# ...
